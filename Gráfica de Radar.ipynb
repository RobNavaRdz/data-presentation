# %% [markdown]
# # Tipos de graficas, usos y significado (3)
#
# ## Diagrama de Radar (Radar diagram)
#
# ### Uso:
# Se usa para representar datos multivariables y compararlos con otros, como pueden ser habilidades de empleados o caracteristicas de un producto
#
# ### Significado:
# Un eje central con al menos 3 aristas en donde los valores son marcados formando un plano que se sobrepone a otros para su comparación.
#
# ### Implementación:
#
# #### Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

categories = ['Food Quality', 'Food Variety', 'Service Quality', 'Ambiance', 'Affordability']
markers = [0, 1, 2, 3, 4, 5]
str_markers = ["0", "1", "2", "3", "4", "5"]

restaurant_1 = [4, 4, 5, 4, 3]
restaurant_2 = [5, 5, 4, 5, 2]
restaurant_3 = [3, 4, 5, 3, 5]
#se concatena la lista original con el primer valor de la lista para cerrar el poligono
restaurant_1 = [*restaurant_1, restaurant_1[0]] 
restaurant_2 = [*restaurant_2, restaurant_2[0]]
restaurant_3 = [*restaurant_3, restaurant_3[0]]
# se definen el numero de angulos de 0 a 2 pi segun la cantidad de categorias
angles = np.linspace(0, 2*np.pi, len(categories), endpoint=False)
angles = np.concatenate((angles,[angles[0]]))

fig = plt.figure(figsize = (7, 5))
ax = fig.add_subplot(111, polar=True)
#restaurant 1
ax.plot(angles, restaurant_1, 'o-', linewidth=2)
ax.fill(angles, restaurant_1, alpha=0.25)
#restaurant 2
ax.plot(angles, restaurant_2, 'o-', linewidth=2)
ax.fill(angles, restaurant_2, alpha=0.25)
#restaurant 3
ax.plot(angles, restaurant_3, 'o-', linewidth=2)
ax.fill(angles, restaurant_3, alpha=0.25)

ax.set_thetagrids(angles * 180/np.pi, labels)
plt.yticks(markers)
ax.set_title("Restaurant comparison")
ax.grid(True)

plt.show()

# %%
import plotly.graph_objects as go

categories = ['Food Quality', 'Food Variety', 'Service Quality', 'Ambience', 'Affordability']
categories = [*categories, categories[0]]

restaurant_1 = [4, 4, 5, 4, 3]
restaurant_2 = [5, 5, 4, 5, 2]
restaurant_3 = [3, 4, 5, 3, 5]
restaurant_1 = [*restaurant_1, restaurant_1[0]]
restaurant_2 = [*restaurant_2, restaurant_2[0]]
restaurant_3 = [*restaurant_3, restaurant_3[0]]

fig = go.Figure(
    data=[go.Scatterpolar(r=restaurant_1, theta=categories, fill='toself', name='Restaurant 1'),
          go.Scatterpolar(r=restaurant_2, theta=categories, fill='toself', name='Restaurant 2'),
          go.Scatterpolar(r=restaurant_3, theta=categories, fill='toself', name='Restaurant 3')],
    layout=go.Layout(title=go.layout.Title(text='Restaurant comparison'),
                     polar={'radialaxis': {'visible': True}},
                     showlegend=True))

fig.show()
# Out:
# <div>                            <div id="3e0605a9-8533-46a0-8b5e-2b243fb1deed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e0605a9-8533-46a0-8b5e-2b243fb1deed")) {                    Plotly.newPlot(                        "3e0605a9-8533-46a0-8b5e-2b243fb1deed",                        [{"fill":"toself","name":"Restaurant 1","r":[4,4,5,4,3,4],"theta":["Food Quality","Food Variety","Service Quality","Ambience","Affordability","Food Quality"],"type":"scatterpolar"},{"fill":"toself","name":"Restaurant 2","r":[5,5,4,5,2,5],"theta":["Food Quality","Food Variety","Service Quality","Ambience","Affordability","Food Quality"],"type":"scatterpolar"},{"fill":"toself","name":"Restaurant 3","r":[3,4,5,3,5,3],"theta":["Food Quality","Food Variety","Service Qu
# ...
